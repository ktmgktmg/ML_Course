# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m,1)

# %%
plt.plot(X, y, "b.")
plt.xlabel('X')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=10, include_bias=False)
X_poly2 = poly_features.fit_transform(X)
X_poly2.shape
# Out:
# (100, 10)

# %%
print(X[0:2])
print(X_poly2[0:2])
# Out:
# [[-0.53111472]
#  [ 0.81990823]]
# [[-0.53111472  0.28208285 -0.14981835  0.07957073]
#  [ 0.81990823  0.67224951  0.55118291  0.45191941]]

# %%
from sklearn.linear_model import LinearRegression
poly_lin_reg = LinearRegression()
poly_lin_reg.fit(X_poly2, y)
print(poly_lin_reg.intercept_, poly_lin_reg.coef_)
# Out:
# [2.74150949] [[ 0.72399228 -1.31736302  0.06333071  1.36760567  0.07395811 -0.43852171
#   -0.02371775  0.06109059  0.00171841 -0.00303908]]

# %%
X_new=np.linspace(-3, 3, 100).reshape(100, 1)
X_new_poly = poly_features.transform(X_new)
y_new = poly_lin_reg.predict(X_new_poly)
y_new[:10]
# Out:
# array([[-0.46653901],
#        [ 1.57762315],
#        [ 2.82634235],
#        [ 3.50064722],
#        [ 3.77384512],
#        [ 3.7796244 ],
#        [ 3.61908874],
#        [ 3.36682977],
#        [ 3.07613634],
#        [ 2.78343181]])

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
y_lin = lin_reg.predict(X_new)

# %%
plt.plot(X, y, "b.")
plt.plot(X_new, y_lin, 'g-', linewidth=2, label="linear Predictions")
plt.plot(X_new, y_new, "r-", linewidth=2, label="Poly Predictions")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([-3, 3, 0, 10])
plt.show()
